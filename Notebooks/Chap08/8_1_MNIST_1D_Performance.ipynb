# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to make a local copy of the MNIST 1D repository
# !git clone https://github.com/greydanus/mnist1d
# Out:
# Cloning into 'mnist1d'...

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d/mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d/mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TO DO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(
  torch.nn.Linear(D_i, D_k),
  torch.nn.ReLU(),
  torch.nn.Linear(D_k, D_k),
  torch.nn.ReLU(),
  torch.nn.Linear(D_k, D_o)
  )

def weights_init(layer_in):
  # TO DO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  if (isinstance(layer_in, torch.nn.Linear)):
    nn.init.kaiming_normal_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Call the function you just defined
model.apply(weights_init)
# Out:
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('long'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch.long())
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train.long()).item()
  losses_test[epoch]= loss_function(pred_test, y_test.long()).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Epoch     0, train loss 1.538955, train error 58.38,  test loss 1.636015, test error 65.20
# Epoch     1, train loss 1.295492, train error 48.17,  test loss 1.447022, test error 56.70
# Epoch     2, train loss 1.105015, train error 39.85,  test loss 1.326840, test error 52.80
# Epoch     3, train loss 0.968318, train error 34.82,  test loss 1.217081, test error 46.80
# Epoch     4, train loss 0.854021, train error 30.38,  test loss 1.170500, test error 44.20
# Epoch     5, train loss 0.777860, train error 27.50,  test loss 1.151007, test error 44.70
# Epoch     6, train loss 0.674836, train error 23.15,  test loss 1.111948, test error 40.20
# Epoch     7, train loss 0.648832, train error 22.88,  test loss 1.197295, test error 44.60
# Epoch     8, train loss 0.584806, train error 20.68,  test loss 1.151019, test error 40.50
# Epoch     9, train loss 0.565798, train error 20.43,  test loss 1.184572, test error 41.70
# Epoch    10, train loss 0.408667, train error 11.55,  test loss 1.073640, test error 39.00
# Epoch    11, train loss 0.374670, train error 10.32,  test loss 1.095034, test error 39.40
# Epoch    12, train loss 0.340739, train error 9.30,  test loss 1.128254, test error 38.80
# Epoch    13, train loss 0.304327, train error 7.05,  test loss 1.117734, test error 37.70
# Epoch    14, train loss 0.290918, train error 7.10,  test loss 1.165018, test error 38.20
# Epoch    15, train loss 0.260109, train error 6.03,  test loss 1.179228, test error 39.20
# Epoch    16, train loss 0.237962, train error 4.80,  test loss 1.190893, test error 38.00
# Epoch    17, train loss 0.211115, train error 3.75,  test loss 1.198693, test error 38.90
# Epoch    18, train loss 0.191216, train error 3.10,  test loss 1.231609, test error 38.50
# Epoch    19, train loss 0.177938, train error 3.10,  test loss 1.273092, test error 38.80
# Epoch    20, train loss 0.153528, train error 1.90,  test loss 1.232734, test error 37.30
# Epoch    21, train loss 0.141633, train error 1.47,  test loss 1.260390, test error 38.90
# Epoch    22, train loss 0.140080, train error 1.68,  test loss 1.288341, test error 37.60
# Epoch    23, train loss 0.126796, train error 1.20,  test loss 1.283759, test error 38.40
# Epoch    24, train loss 0.121294, train error 1.00,  test loss 1.288254, test error 37.90
# Epoch    25, train loss 0.114639, train error 0.80,  test loss 1.305913, test error 38.10
# Epoch    26, train loss 0.108411, train error 0.70,  test loss 1.304786, test error 38.30
# Epoch    27, train loss 0.106026, train error 0.60,  test loss 1.332682, test error 37.90
# Epoch    28, train loss 0.097960, train error 0.53,  test loss 1.339251, test error 38.10
# Epoch    29, train loss 0.094325, train error 0.50,  test loss 1.339071, test error 37.80
# Epoch    30, train loss 0.089297, train error 0.38,  test loss 1.353035, test error 37.70
# Epoch    31, train loss 0.086848, train error 0.35,  test loss 1.357802, test error 37.30
# Epoch    32, train loss 0.085010, train error 0.38,  test loss 1.360486, test error 38.20
# Epoch    33, train loss 0.082274, train error 0.32,  test loss 1.370464, test error 37.80
# Epoch    34, train loss 0.080914, train error 0.32,  test loss 1.372394, test error 37.90
# Epoch    35, train loss 0.079374, train error 0.28,  test loss 1.383728, test error 38.70
# Epoch    36, train loss 0.077400, train error 0.30,  test loss 1.389776, test error 37.60
# Epoch    37, train loss 0.075213, train error 0.25,  test loss 1.390364, test error 37.10
# Epoch    38, train loss 0.073442, train error 0.28,  test loss 1.395898, test error 37.20
# Epoch    39, train loss 0.072246, train error 0.22,  test loss 1.403809, test error 37.80
# Epoch    40, train loss 0.070775, train error 0.22,  test loss 1.405371, test error 37.80
# Epoch    41, train loss 0.070048, train error 0.18,  test loss 1.406556, test error 37.50
# Epoch    42, train loss 0.069224, train error 0.18,  test loss 1.410855, test error 37.60
# Epoch    43, train loss 0.068582, train error 0.20,  test loss 1.416926, test error 37.70
# Epoch    44, train loss 0.067746, train error 0.15,  test loss 1.416890, test error 37.60
# Epoch    45, train loss 0.067080, train error 0.18,  test loss 1.421342, test error 37.20
# Epoch    46, train loss 0.066367, train error 0.18,  test loss 1.425769, test error 37.50
# Epoch    47, train loss 0.065906, train error 0.15,  test loss 1.428363, test error 37.30
# Epoch    48, train loss 0.064952, train error 0.15,  test loss 1.429744, test error 37.70
# Epoch    49, train loss 0.064308, train error 0.12,  test loss 1.429694, test error 37.80

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TO DO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
