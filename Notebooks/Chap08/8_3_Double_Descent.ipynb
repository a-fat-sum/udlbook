# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to make a local copy of the MNIST 1D repository
# !git clone https://github.com/greydanus/mnist1d

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cpu

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d/mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d/mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Length of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  # loop over the dataset n_epoch times
  n_epoch = 1000

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch.long())
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train.long()).item()
    losses_test= loss_function(pred_test, y_test.long()).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;
errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Train the model
    errors_train, errors_test = fit_model(model, data)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.303033, train error 89.88,  test loss 2.303623, test error 90.10
# Epoch   100, train loss 1.949455, train error 73.78,  test loss 1.821110, test error 72.45
# Epoch   200, train loss 1.920113, train error 73.25,  test loss 1.755394, test error 69.28
# Epoch   300, train loss 1.914478, train error 72.12,  test loss 1.736566, test error 68.90
# Epoch   400, train loss 1.911719, train error 72.28,  test loss 1.732799, test error 70.00
# Epoch   500, train loss 1.904943, train error 71.60,  test loss 1.735729, test error 69.80
# Epoch   600, train loss 1.906942, train error 71.03,  test loss 1.736672, test error 70.07
# Epoch   700, train loss 1.908216, train error 72.07,  test loss 1.741984, test error 68.78
# Epoch   800, train loss 1.908184, train error 71.18,  test loss 1.732426, test error 70.40
# Epoch   900, train loss 1.905710, train error 72.32,  test loss 1.733788, test error 69.47
# Training model with   4 hidden variables
# Epoch     0, train loss 2.262541, train error 85.88,  test loss 2.256885, test error 86.53
# Epoch   100, train loss 1.882132, train error 69.93,  test loss 1.744263, test error 69.05
# Epoch   200, train loss 1.847654, train error 68.88,  test loss 1.704803, test error 67.60
# Epoch   300, train loss 1.818579, train error 67.45,  test loss 1.701914, test error 66.20
# Epoch   400, train loss 1.767401, train error 63.90,  test loss 1.640396, test error 61.72
# Epoch   500, train loss 1.765273, train error 63.72,  test loss 1.641711, test error 61.75
# Epoch   600, train loss 1.766423, train error 63.12,  test loss 1.658497, test error 62.40
# Epoch   700, train loss 1.768332, train error 63.97,  test loss 1.646878, test error 62.15
# Epoch   800, train loss 1.756312, train error 63.47,  test loss 1.648727, test error 62.45
# Epoch   900, train loss 1.755773, train error 63.35,  test loss 1.644768, test error 62.62
# Training model with   6 hidden variables
# Epoch     0, train loss 2.286300, train error 87.35,  test loss 2.280485, test error 86.80
# Epoch   100, train loss 1.703056, train error 61.05,  test loss 1.560384, test error 59.55
# Epoch   200, train loss 1.638675, train error 58.38,  test loss 1.505848, test error 57.20
# Epoch   300, train loss 1.621443, train error 57.25,  test loss 1.483629, test error 56.08
# Epoch   400, train loss 1.616808, train error 57.35,  test loss 1.474777, test error 55.20
# Epoch   500, train loss 1.614351, train error 56.80,  test loss 1.469554, test error 54.88
# Epoch   600, train loss 1.610885, train error 56.85,  test loss 1.481558, test error 55.22
# Epoch   700, train loss 1.614188, train error 57.05,  test loss 1.489655, test error 55.83
# Epoch   800, train loss 1.609442, train error 56.25,  test loss 1.487430, test error 55.00
# Epoch   900, train loss 1.605990, train error 56.70,  test loss 1.485559, test error 55.15
# Training model with   8 hidden variables
# Epoch     0, train loss 2.242853, train error 82.90,  test loss 2.234648, test error 82.12
# Epoch   100, train loss 1.600326, train error 56.28,  test loss 1.472564, test error 56.17
# Epoch   200, train loss 1.567024, train error 54.97,  test loss 1.470141, test error 56.88
# Epoch   300, train loss 1.535820, train error 53.25,  test loss 1.449176, test error 55.08
# Epoch   400, train loss 1.524066, train error 53.70,  test loss 1.443541, test error 54.88
# Epoch   500, train loss 1.512073, train error 53.92,  test loss 1.440474, test error 53.83
# Epoch   600, train loss 1.505587, train error 53.30,  test loss 1.439184, test error 54.10
# Epoch   700, train loss 1.507647, train error 52.92,  test loss 1.438560, test error 53.85
# Epoch   800, train loss 1.501262, train error 52.47,  test loss 1.438032, test error 53.92
# Epoch   900, train loss 1.499217, train error 52.33,  test loss 1.440073, test error 54.00
# Training model with  10 hidden variables
# Epoch     0, train loss 2.298294, train error 88.53,  test loss 2.297790, test error 88.78
# Epoch   100, train loss 1.609356, train error 55.65,  test loss 1.461961, test error 56.28
# Epoch   200, train loss 1.504392, train error 52.10,  test loss 1.390474, test error 52.40
# Epoch   300, train loss 1.476655, train error 51.72,  test loss 1.391213, test error 51.80
# Epoch   400, train loss 1.456800, train error 50.38,  test loss 1.386634, test error 52.30
# Epoch   500, train loss 1.447475, train error 50.45,  test loss 1.401239, test error 52.78
# Epoch   600, train loss 1.437479, train error 50.12,  test loss 1.399537, test error 52.42
# Epoch   700, train loss 1.446844, train error 50.70,  test loss 1.425948, test error 53.55
# Epoch   800, train loss 1.432750, train error 49.75,  test loss 1.422896, test error 54.05
# Epoch   900, train loss 1.424070, train error 49.78,  test loss 1.424327, test error 53.45
# Training model with  14 hidden variables
# Epoch     0, train loss 2.277500, train error 85.97,  test loss 2.259396, test error 85.00
# Epoch   100, train loss 1.506346, train error 52.60,  test loss 1.422035, test error 54.62
# Epoch   200, train loss 1.444054, train error 50.70,  test loss 1.454498, test error 55.42
# Epoch   300, train loss 1.405288, train error 48.42,  test loss 1.485813, test error 56.00
# Epoch   400, train loss 1.387465, train error 47.50,  test loss 1.502003, test error 55.97
# Epoch   500, train loss 1.373536, train error 47.65,  test loss 1.527884, test error 55.70
# Epoch   600, train loss 1.357537, train error 47.30,  test loss 1.572556, test error 56.78
# Epoch   700, train loss 1.346608, train error 46.60,  test loss 1.584515, test error 56.50
# Epoch   800, train loss 1.333181, train error 45.88,  test loss 1.591151, test error 55.80
# Epoch   900, train loss 1.337025, train error 46.47,  test loss 1.607387, test error 56.53
# Training model with  18 hidden variables
# Epoch     0, train loss 2.130049, train error 80.45,  test loss 2.101496, test error 79.18
# Epoch   100, train loss 1.345310, train error 44.62,  test loss 1.306123, test error 48.83
# Epoch   200, train loss 1.226089, train error 40.17,  test loss 1.319299, test error 47.55
# Epoch   300, train loss 1.187060, train error 39.67,  test loss 1.360882, test error 48.40
# Epoch   400, train loss 1.167251, train error 39.50,  test loss 1.378792, test error 47.72
# Epoch   500, train loss 1.144718, train error 39.03,  test loss 1.410911, test error 48.75
# Epoch   600, train loss 1.145917, train error 38.05,  test loss 1.444466, test error 49.47
# Epoch   700, train loss 1.132588, train error 37.92,  test loss 1.462179, test error 49.67
# Epoch   800, train loss 1.131469, train error 37.58,  test loss 1.483835, test error 49.38
# Epoch   900, train loss 1.112670, train error 36.50,  test loss 1.496501, test error 49.97
# Training model with  22 hidden variables
# Epoch     0, train loss 2.171167, train error 80.90,  test loss 2.128545, test error 81.07
# Epoch   100, train loss 1.257621, train error 41.33,  test loss 1.286815, test error 47.15
# Epoch   200, train loss 1.140530, train error 36.75,  test loss 1.370719, test error 48.92
# Epoch   300, train loss 1.090216, train error 35.12,  test loss 1.448317, test error 50.25
# Epoch   400, train loss 1.076492, train error 35.55,  test loss 1.493871, test error 50.53
# Epoch   500, train loss 1.042133, train error 34.40,  test loss 1.556001, test error 50.90
# Epoch   600, train loss 1.040222, train error 34.20,  test loss 1.599541, test error 51.38
# Epoch   700, train loss 1.012247, train error 32.93,  test loss 1.605095, test error 51.70
# Epoch   800, train loss 1.007683, train error 33.28,  test loss 1.659131, test error 52.38
# Epoch   900, train loss 0.999343, train error 33.25,  test loss 1.655572, test error 51.10
# Training model with  26 hidden variables
# Epoch     0, train loss 2.164354, train error 78.78,  test loss 2.131106, test error 78.82
# Epoch   100, train loss 1.155144, train error 37.35,  test loss 1.301879, test error 47.12
# Epoch   200, train loss 1.001720, train error 32.88,  test loss 1.428589, test error 50.00
# Epoch   300, train loss 0.930886, train error 29.88,  test loss 1.554785, test error 51.20
# Epoch   400, train loss 0.892642, train error 29.93,  test loss 1.633498, test error 50.67
# Epoch   500, train loss 0.858335, train error 28.68,  test loss 1.775203, test error 52.85
# Epoch   600, train loss 0.862713, train error 28.70,  test loss 1.813547, test error 51.90
# Epoch   700, train loss 0.823461, train error 27.43,  test loss 1.884969, test error 53.55
# Epoch   800, train loss 0.830046, train error 28.90,  test loss 1.952289, test error 54.70
# Epoch   900, train loss 0.813657, train error 28.22,  test loss 1.975553, test error 54.10
# Training model with  30 hidden variables
# Epoch     0, train loss 2.202962, train error 81.32,  test loss 2.190898, test error 81.35
# Epoch   100, train loss 1.114169, train error 36.40,  test loss 1.331521, test error 48.80
# Epoch   200, train loss 0.930168, train error 30.45,  test loss 1.534870, test error 51.95
# Epoch   300, train loss 0.825600, train error 26.97,  test loss 1.702373, test error 51.92
# Epoch   400, train loss 0.762238, train error 25.07,  test loss 1.864569, test error 52.42
# Epoch   500, train loss 0.715009, train error 24.03,  test loss 2.031568, test error 53.15
# Epoch   600, train loss 0.695768, train error 23.32,  test loss 2.214285, test error 53.85
# Epoch   700, train loss 0.671503, train error 22.55,  test loss 2.388402, test error 54.72
# Epoch   800, train loss 0.655961, train error 22.35,  test loss 2.506923, test error 55.22
# Epoch   900, train loss 0.658358, train error 22.43,  test loss 2.626236, test error 55.38
# Training model with  35 hidden variables
# Epoch     0, train loss 2.107195, train error 77.90,  test loss 2.044488, test error 77.25
# Epoch   100, train loss 0.992393, train error 31.85,  test loss 1.436603, test error 51.20
# Epoch   200, train loss 0.766728, train error 24.80,  test loss 1.769616, test error 53.15
# Epoch   300, train loss 0.655624, train error 21.28,  test loss 2.092820, test error 53.33
# Epoch   400, train loss 0.606965, train error 20.47,  test loss 2.556918, test error 55.72
# Epoch   500, train loss 0.550823, train error 17.57,  test loss 2.785119, test error 55.20
# Epoch   600, train loss 0.515260, train error 16.93,  test loss 3.060374, test error 55.72
# Epoch   700, train loss 0.494295, train error 16.75,  test loss 3.344305, test error 56.25
# Epoch   800, train loss 0.486745, train error 16.82,  test loss 3.697471, test error 56.08
# Epoch   900, train loss 0.428728, train error 14.03,  test loss 3.929583, test error 57.78
# Training model with  40 hidden variables
# Epoch     0, train loss 2.102633, train error 78.57,  test loss 2.060664, test error 78.07
# Epoch   100, train loss 0.915091, train error 29.20,  test loss 1.451680, test error 50.88
# Epoch   200, train loss 0.654808, train error 21.35,  test loss 1.907454, test error 52.25
# Epoch   300, train loss 0.515332, train error 17.60,  test loss 2.501128, test error 54.45
# Epoch   400, train loss 0.455359, train error 16.00,  test loss 3.069606, test error 56.12
# Epoch   500, train loss 0.393507, train error 14.30,  test loss 3.725974, test error 57.05
# Epoch   600, train loss 0.386942, train error 13.95,  test loss 4.279580, test error 56.70
# Epoch   700, train loss 0.334519, train error 12.15,  test loss 4.827936, test error 57.50
# Epoch   800, train loss 0.271656, train error 9.55,  test loss 5.412638, test error 57.85
# Epoch   900, train loss 0.303826, train error 11.28,  test loss 5.986592, test error 57.72
# Training model with  45 hidden variables
# Epoch     0, train loss 2.051234, train error 76.18,  test loss 1.984969, test error 76.25
# Epoch   100, train loss 0.783699, train error 24.72,  test loss 1.554965, test error 50.35
# Epoch   200, train loss 0.457182, train error 13.80,  test loss 2.343254, test error 54.05
# Epoch   300, train loss 0.273904, train error 7.80,  test loss 3.524942, test error 54.80
# Epoch   400, train loss 0.185938, train error 5.55,  test loss 4.829012, test error 55.62
# Epoch   500, train loss 0.111913, train error 2.82,  test loss 6.263338, test error 56.38
# Epoch   600, train loss 0.023387, train error 0.00,  test loss 7.455442, test error 55.95
# Epoch   700, train loss 0.011541, train error 0.00,  test loss 8.392998, test error 56.25
# Epoch   800, train loss 0.008016, train error 0.00,  test loss 9.005133, test error 56.10
# Epoch   900, train loss 0.006199, train error 0.00,  test loss 9.498303, test error 56.17
# Training model with  50 hidden variables
# Epoch     0, train loss 2.092869, train error 78.80,  test loss 2.018676, test error 75.90
# Epoch   100, train loss 0.739077, train error 23.35,  test loss 1.479088, test error 49.28
# Epoch   200, train loss 0.341915, train error 8.95,  test loss 2.556748, test error 54.35
# Epoch   300, train loss 0.155987, train error 4.00,  test loss 4.029323, test error 54.83
# Epoch   400, train loss 0.028039, train error 0.00,  test loss 5.643933, test error 55.78
# Epoch   500, train loss 0.012639, train error 0.00,  test loss 6.536695, test error 55.95
# Epoch   600, train loss 0.007895, train error 0.00,  test loss 7.135565, test error 55.97
# Epoch   700, train loss 0.005674, train error 0.00,  test loss 7.568823, test error 55.65
# Epoch   800, train loss 0.004375, train error 0.00,  test loss 7.919612, test error 55.78
# Epoch   900, train loss 0.003507, train error 0.00,  test loss 8.214088, test error 55.78
# Training model with  55 hidden variables
# Epoch     0, train loss 2.063497, train error 77.53,  test loss 2.005864, test error 76.95
# Epoch   100, train loss 0.638469, train error 19.32,  test loss 1.665308, test error 52.50
# Epoch   200, train loss 0.207638, train error 4.60,  test loss 2.957415, test error 55.05
# Epoch   300, train loss 0.041774, train error 0.00,  test loss 4.571629, test error 55.10
# Epoch   400, train loss 0.013871, train error 0.00,  test loss 5.521263, test error 55.15
# Epoch   500, train loss 0.008185, train error 0.00,  test loss 6.108940, test error 55.28
# Epoch   600, train loss 0.005674, train error 0.00,  test loss 6.524579, test error 55.20
# Epoch   700, train loss 0.004270, train error 0.00,  test loss 6.853443, test error 55.15
# Epoch   800, train loss 0.003385, train error 0.00,  test loss 7.115781, test error 55.22
# Epoch   900, train loss 0.002782, train error 0.00,  test loss 7.339280, test error 55.17
# Training model with  60 hidden variables
# Epoch     0, train loss 2.080199, train error 76.47,  test loss 2.039988, test error 76.30
# Epoch   100, train loss 0.543525, train error 15.85,  test loss 1.710835, test error 49.88
# Epoch   200, train loss 0.112311, train error 1.45,  test loss 3.358449, test error 54.05
# Epoch   300, train loss 0.020258, train error 0.00,  test loss 4.658628, test error 54.15
# Epoch   400, train loss 0.009807, train error 0.00,  test loss 5.345642, test error 54.25
# Epoch   500, train loss 0.006220, train error 0.00,  test loss 5.797955, test error 54.50
# Epoch   600, train loss 0.004425, train error 0.00,  test loss 6.127846, test error 54.58
# Epoch   700, train loss 0.003396, train error 0.00,  test loss 6.395022, test error 54.55
# Epoch   800, train loss 0.002734, train error 0.00,  test loss 6.615231, test error 54.65
# Epoch   900, train loss 0.002264, train error 0.00,  test loss 6.805248, test error 54.78
# Training model with  70 hidden variables
# Epoch     0, train loss 2.049598, train error 75.95,  test loss 1.989957, test error 76.55
# Epoch   100, train loss 0.374502, train error 9.43,  test loss 1.922776, test error 51.97
# Epoch   200, train loss 0.036473, train error 0.00,  test loss 3.641245, test error 54.47
# Epoch   300, train loss 0.011505, train error 0.00,  test loss 4.482293, test error 54.75
# Epoch   400, train loss 0.006342, train error 0.00,  test loss 4.952006, test error 54.80
# Epoch   500, train loss 0.004226, train error 0.00,  test loss 5.280674, test error 54.90
# Epoch   600, train loss 0.003118, train error 0.00,  test loss 5.526987, test error 55.03
# Epoch   700, train loss 0.002450, train error 0.00,  test loss 5.728527, test error 55.15
# Epoch   800, train loss 0.001993, train error 0.00,  test loss 5.894975, test error 55.12
# Epoch   900, train loss 0.001673, train error 0.00,  test loss 6.037568, test error 55.17
# Training model with  80 hidden variables
# Epoch     0, train loss 2.004196, train error 74.18,  test loss 1.969340, test error 76.18
# Epoch   100, train loss 0.220730, train error 3.38,  test loss 2.120638, test error 53.00
# Epoch   200, train loss 0.020530, train error 0.00,  test loss 3.497287, test error 53.42
# Epoch   300, train loss 0.008159, train error 0.00,  test loss 4.072152, test error 53.47
# Epoch   400, train loss 0.004840, train error 0.00,  test loss 4.417966, test error 53.47
# Epoch   500, train loss 0.003350, train error 0.00,  test loss 4.659883, test error 53.62
# Epoch   600, train loss 0.002521, train error 0.00,  test loss 4.847159, test error 53.60
# Epoch   700, train loss 0.002000, train error 0.00,  test loss 4.999812, test error 53.62
# Epoch   800, train loss 0.001647, train error 0.00,  test loss 5.127808, test error 53.70
# Epoch   900, train loss 0.001393, train error 0.00,  test loss 5.239686, test error 53.80
# Training model with  90 hidden variables
# Epoch     0, train loss 2.007455, train error 73.75,  test loss 1.937788, test error 74.00
# Epoch   100, train loss 0.142713, train error 1.30,  test loss 2.269727, test error 52.35
# Epoch   200, train loss 0.014514, train error 0.00,  test loss 3.283359, test error 52.12
# Epoch   300, train loss 0.006429, train error 0.00,  test loss 3.710313, test error 52.35
# Epoch   400, train loss 0.003942, train error 0.00,  test loss 3.978008, test error 52.62
# Epoch   500, train loss 0.002777, train error 0.00,  test loss 4.169665, test error 52.42
# Epoch   600, train loss 0.002116, train error 0.00,  test loss 4.317331, test error 52.50
# Epoch   700, train loss 0.001695, train error 0.00,  test loss 4.441597, test error 52.47
# Epoch   800, train loss 0.001404, train error 0.00,  test loss 4.545061, test error 52.58
# Epoch   900, train loss 0.001193, train error 0.00,  test loss 4.634026, test error 52.53
# Training model with 100 hidden variables
# Epoch     0, train loss 1.974449, train error 73.15,  test loss 1.892608, test error 71.93
# Epoch   100, train loss 0.100149, train error 0.18,  test loss 2.249662, test error 51.33
# Epoch   200, train loss 0.012506, train error 0.00,  test loss 3.121431, test error 51.97
# Epoch   300, train loss 0.005738, train error 0.00,  test loss 3.499727, test error 52.33
# Epoch   400, train loss 0.003579, train error 0.00,  test loss 3.732460, test error 52.28
# Epoch   500, train loss 0.002537, train error 0.00,  test loss 3.909412, test error 52.62
# Epoch   600, train loss 0.001945, train error 0.00,  test loss 4.043548, test error 52.55
# Epoch   700, train loss 0.001562, train error 0.00,  test loss 4.154265, test error 52.55
# Epoch   800, train loss 0.001297, train error 0.00,  test loss 4.248255, test error 52.47
# Epoch   900, train loss 0.001104, train error 0.00,  test loss 4.330453, test error 52.50
# Training model with 120 hidden variables
# Epoch     0, train loss 1.993277, train error 73.57,  test loss 1.918257, test error 73.60
# Epoch   100, train loss 0.053595, train error 0.00,  test loss 2.350646, test error 52.38
# Epoch   200, train loss 0.009815, train error 0.00,  test loss 3.025736, test error 51.47
# Epoch   300, train loss 0.004815, train error 0.00,  test loss 3.326894, test error 51.67
# Epoch   400, train loss 0.003074, train error 0.00,  test loss 3.524229, test error 51.67
# Epoch   500, train loss 0.002215, train error 0.00,  test loss 3.668900, test error 51.55
# Epoch   600, train loss 0.001710, train error 0.00,  test loss 3.782012, test error 51.62
# Epoch   700, train loss 0.001382, train error 0.00,  test loss 3.877529, test error 51.70
# Epoch   800, train loss 0.001153, train error 0.00,  test loss 3.958016, test error 51.65
# Epoch   900, train loss 0.000986, train error 0.00,  test loss 4.028502, test error 51.85
# Training model with 140 hidden variables
# Epoch     0, train loss 1.968618, train error 72.72,  test loss 1.921393, test error 73.55
# Epoch   100, train loss 0.037412, train error 0.00,  test loss 2.203412, test error 50.17
# Epoch   200, train loss 0.008396, train error 0.00,  test loss 2.717440, test error 50.17
# Epoch   300, train loss 0.004306, train error 0.00,  test loss 2.960690, test error 50.15
# Epoch   400, train loss 0.002790, train error 0.00,  test loss 3.118594, test error 50.12
# Epoch   500, train loss 0.002028, train error 0.00,  test loss 3.236726, test error 50.20
# Epoch   600, train loss 0.001575, train error 0.00,  test loss 3.331072, test error 50.22
# Epoch   700, train loss 0.001278, train error 0.00,  test loss 3.409872, test error 50.17
# Epoch   800, train loss 0.001069, train error 0.00,  test loss 3.477195, test error 50.28
# Epoch   900, train loss 0.000915, train error 0.00,  test loss 3.534753, test error 50.33
# Training model with 160 hidden variables
# Epoch     0, train loss 1.933899, train error 71.88,  test loss 1.838420, test error 70.80
# Epoch   100, train loss 0.028186, train error 0.00,  test loss 2.097713, test error 49.25
# Epoch   200, train loss 0.007160, train error 0.00,  test loss 2.507307, test error 48.83
# Epoch   300, train loss 0.003764, train error 0.00,  test loss 2.708396, test error 48.95
# Epoch   400, train loss 0.002477, train error 0.00,  test loss 2.840981, test error 48.88
# Epoch   500, train loss 0.001815, train error 0.00,  test loss 2.940604, test error 48.88
# Epoch   600, train loss 0.001418, train error 0.00,  test loss 3.019250, test error 48.85
# Epoch   700, train loss 0.001155, train error 0.00,  test loss 3.085313, test error 48.85
# Epoch   800, train loss 0.000969, train error 0.00,  test loss 3.141452, test error 48.83
# Epoch   900, train loss 0.000832, train error 0.00,  test loss 3.190983, test error 48.88
# Training model with 180 hidden variables
# Epoch     0, train loss 1.927791, train error 70.00,  test loss 1.822365, test error 71.05
# Epoch   100, train loss 0.022989, train error 0.00,  test loss 1.996157, test error 47.30
# Epoch   200, train loss 0.006379, train error 0.00,  test loss 2.331614, test error 47.20
# Epoch   300, train loss 0.003440, train error 0.00,  test loss 2.503829, test error 47.28
# Epoch   400, train loss 0.002285, train error 0.00,  test loss 2.620715, test error 47.17
# Epoch   500, train loss 0.001684, train error 0.00,  test loss 2.707144, test error 47.35
# Epoch   600, train loss 0.001321, train error 0.00,  test loss 2.777565, test error 47.38
# Epoch   700, train loss 0.001079, train error 0.00,  test loss 2.835276, test error 47.40
# Epoch   800, train loss 0.000908, train error 0.00,  test loss 2.885229, test error 47.40
# Epoch   900, train loss 0.000781, train error 0.00,  test loss 2.928013, test error 47.35
# Training model with 200 hidden variables
# Epoch     0, train loss 1.909832, train error 69.15,  test loss 1.848398, test error 70.95
# Epoch   100, train loss 0.021190, train error 0.00,  test loss 2.028261, test error 48.67
# Epoch   200, train loss 0.006074, train error 0.00,  test loss 2.353038, test error 48.33
# Epoch   300, train loss 0.003282, train error 0.00,  test loss 2.519053, test error 48.42
# Epoch   400, train loss 0.002190, train error 0.00,  test loss 2.629229, test error 48.22
# Epoch   500, train loss 0.001617, train error 0.00,  test loss 2.713759, test error 48.20
# Epoch   600, train loss 0.001270, train error 0.00,  test loss 2.780928, test error 48.10
# Epoch   700, train loss 0.001039, train error 0.00,  test loss 2.837490, test error 48.20
# Epoch   800, train loss 0.000875, train error 0.00,  test loss 2.886058, test error 48.15
# Epoch   900, train loss 0.000753, train error 0.00,  test loss 2.928778, test error 48.10
# Training model with 250 hidden variables
# Epoch     0, train loss 1.901563, train error 69.03,  test loss 1.844222, test error 71.32
# Epoch   100, train loss 0.016634, train error 0.00,  test loss 1.975300, test error 47.67
# Epoch   200, train loss 0.005271, train error 0.00,  test loss 2.236093, test error 47.38
# Epoch   300, train loss 0.002928, train error 0.00,  test loss 2.374154, test error 47.20
# Epoch   400, train loss 0.001980, train error 0.00,  test loss 2.469198, test error 47.25
# Epoch   500, train loss 0.001475, train error 0.00,  test loss 2.542004, test error 47.22
# Epoch   600, train loss 0.001165, train error 0.00,  test loss 2.600442, test error 47.25
# Epoch   700, train loss 0.000957, train error 0.00,  test loss 2.650239, test error 47.15
# Epoch   800, train loss 0.000808, train error 0.00,  test loss 2.692526, test error 47.12
# Epoch   900, train loss 0.000698, train error 0.00,  test loss 2.729966, test error 47.15
# Training model with 300 hidden variables
# Epoch     0, train loss 1.906375, train error 68.57,  test loss 1.844387, test error 70.68
# Epoch   100, train loss 0.014547, train error 0.00,  test loss 1.889298, test error 47.50
# Epoch   200, train loss 0.004826, train error 0.00,  test loss 2.108684, test error 47.28
# Epoch   300, train loss 0.002719, train error 0.00,  test loss 2.227001, test error 47.20
# Epoch   400, train loss 0.001852, train error 0.00,  test loss 2.308622, test error 46.97
# Epoch   500, train loss 0.001386, train error 0.00,  test loss 2.370279, test error 46.83
# Epoch   600, train loss 0.001098, train error 0.00,  test loss 2.420642, test error 46.80
# Epoch   700, train loss 0.000904, train error 0.00,  test loss 2.462792, test error 46.90
# Epoch   800, train loss 0.000766, train error 0.00,  test loss 2.499302, test error 47.00
# Epoch   900, train loss 0.000662, train error 0.00,  test loss 2.531249, test error 46.92
# Training model with 400 hidden variables
# Epoch     0, train loss 1.828381, train error 65.50,  test loss 1.774852, test error 68.95
# Epoch   100, train loss 0.011598, train error 0.00,  test loss 1.697109, test error 45.53
# Epoch   200, train loss 0.004168, train error 0.00,  test loss 1.865411, test error 45.25
# Epoch   300, train loss 0.002404, train error 0.00,  test loss 1.957249, test error 45.33
# Epoch   400, train loss 0.001657, train error 0.00,  test loss 2.021703, test error 45.12
# Epoch   500, train loss 0.001248, train error 0.00,  test loss 2.070559, test error 45.12
# Epoch   600, train loss 0.000994, train error 0.00,  test loss 2.110642, test error 45.12
# Epoch   700, train loss 0.000822, train error 0.00,  test loss 2.144032, test error 45.15
# Epoch   800, train loss 0.000698, train error 0.00,  test loss 2.173345, test error 45.25
# Epoch   900, train loss 0.000605, train error 0.00,  test loss 2.198893, test error 45.12

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all,'r-',label='train')
ax.plot(hidden_variables, errors_test_all,'b-',label='test')
ax.set_ylim(0,100);
ax.set_xlabel('No hidden variables'); ax.set_ylabel('Error')
ax.legend()
plt.show()
